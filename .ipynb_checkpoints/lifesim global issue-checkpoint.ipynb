# %%
#life sim

# %%
import random
import time
import random
import numpy as np

# %%
print("hello")
time.sleep(3)
print("there")

# %%
def intro():
    
    print("Welcome you where born in an affair ")
    print("Your name is  ")
    print("You are born in America")
    print()

# %%
names=["Jacobus","Ruan","Dina","Michael","Brendan","Shana","Dirk","Werner"]
country=["Amreica","France","Australia","Switzerland","China","Scotland","Portugal","South Africa","Argentina","Mexico","Nigeria","India",]
concieved=["an affair","a planned pregnancy","a scandal","a Lab","an adoption","a cardboard box"]
health=[]
happiness=[]
intelligence=[]

looks=[]
age=0
a=random.randint(0,len(concieved)-1)
b=random.randint(0,7)
c=random.randint(0,len(country)-1)

    
    
    
    
    
print("Welcome you were born in ",concieved[a])
print("Your name is:",names[b] )
print("You are born in:",country[c])
print()
print("age :",age)
print()
if  a== 5:
    print("unfortunately your parents did not love you enough and left you to die")
    print()
    print("game over")
        
else:    
    print("your stats at birth are:")
        
    if c <= 6 :
        health=100
        happiness=random.randint(80,100)
        intelligence=random.randint(40,100)
        looks=random.randint(0,100)
        print("health:",health)
        print("happiness:",happiness)
        print("intelligence:",intelligence)
        print("Looks:",looks)
    elif c > 6 and c <= 9:
        health=random.randint(60,90)
        happiness=random.randint(0,80)
        intelligence=random.randint(10,100)
        looks=random.randint(0,100)
        print("health:",health)
        print("happiness:",happiness)
        print("intelligence:",intelligence)
        print("Looks:",looks)
    elif c> 10:
        health=random.randint(5,50)
        happiness=random.randint(0,70)
        intelligence=random.randint(10,100)
        looks=random.randint(0,100)
        print("health:",health)
        print("happiness:",happiness)
        print("intelligence:",intelligence)
        print("Looks:",looks)
    
    
def path():
    
    path = ""
    while path != "1" and path != "2":
        path = input ("age up? (1 for yes or 2 for no): ")
        
    return path

def checkpath(path):
    
    if path == '1':
        print("You age up")
        print("age:",age+1)
        time.sleep(2)
        print("your new stats are: ")
        
        if c <= 6 :
                intro=100
                happiness=happiness+ random.randint(-2,2)
                intelligence=intelligence+random.randint(-2,2)
                looks=looks+random.randint(-2,2)
                print("health:",health)
                print("happiness:",happiness)
                print("intelligence:",intelligence)
                print("Looks:",looks)
        elif c > 6 and c <= 9:
                health=health+ random.randint(-2,2)
                happiness=happines+ random.randint(-2,2)
                intelligence=intelligence+random.randint(-2,2)
                looks=looks+random.randint(-2,2)
                print("health:",health)
                print("happiness:",happiness)
                print("intelligence:",intelligence)
                print("Looks:",looks)
        elif c> 10:
                health=health+ random.randint(-2,2)
                happiness=happines+ random.randint(-2,2)
                intelligence=intelligence+random.randint(-2,2)
                looks=looks+random.randint(-2,2)
                print("health:",health)
                print("happiness:",happiness)
                print("intelligence:",intelligence)
                print("Looks:",looks)
    else:
        print("your age is :",age)
        print("your stats are: ")
        print("health:",health)
        print("happiness:",happiness)
        print("intelligence:",intelligence)
        print("Looks:",looks)

playagain= "yes"
while playagain=="yes" or playagain=="y":
    
    choice = path()
    checkpath(choice)
    playagain= input("do you want to play again? (yes or y to play again):")
# Out:
# Welcome you were born in  a scandal
# Your name is: Ruan
# You are born in: Mexico
#
# age : 0
#
# your stats at birth are:
# health: 68
# happiness: 51
# intelligence: 89
# Looks: 81
# age up? (1 for yes or 2 for no): 1
# You age up
# age: 1
# your new stats are:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-8fcaee76970c> in <module>
#     115
#     116     choice = path()
# --> 117     checkpath(choice)
#     118     playagain= input("do you want to play again? (yes or y to play again):")
#
# <ipython-input-3-8fcaee76970c> in checkpath(path)
#      86                 print("Looks:",looks)
#      87         elif c > 6 and c <= 9:
# ---> 88                 health=health+ random.randint(-2,2)
#      89                 happiness=happines+ random.randint(-2,2)
#      90                 intelligence=intelligence+random.randint(-2,2)
#
# UnboundLocalError: local variable 'health' referenced before assignment

# %%
intro()
Path()

# %%
def intro():
    
    
    
    
    
    print("Welcome you were born in ",concieved[a])
    print("Your name is:",names[b] )
    print("You are born in:",country[c])
    print()
    print("age :",age)
    print()
    if  a== 5:
        print("unfortunately your parents did not love you enough and left you to die")
        print()
        print("game over")
        
    else:    
        print("your stats at birth are:")
        
        if c <= 6 :
            health=100
            happiness=random.randint(80,100)
            intelligence=random.randint(40,100)
            looks=random.randint(0,100)
            print("health:",health)
            print("happiness:",happiness)
            print("intelligence:",intelligence)
            print("Looks:",looks)
        elif c > 6 and c <= 9:
            health=random.randint(60,90)
            happiness=random.randint(0,80)
            intelligence=random.randint(10,100)
            looks=random.randint(0,100)
            print("health:",health)
            print("happiness:",happiness)
            print("intelligence:",intelligence)
            print("Looks:",looks)
        elif c> 10:
            health=random.randint(5,50)
            happiness=random.randint(0,70)
            intelligence=random.randint(10,100)
            looks=random.randint(0,100)
            print("health:",health)
            print("happiness:",happiness)
            print("intelligence:",intelligence)
            print("Looks:",looks)
    return(health,happiness,intelligence,looks)

# %%
intro()
